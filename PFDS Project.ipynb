# %% [markdown]
# # URBAN TRAFIIC ANALYSIS USING PYTHON

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df =pd.read_csv('futuristic_city_traffic.csv')

# %%
df
# Out:
#                  City        Vehicle Type                Weather  \
# 0        SolarisVille               Drone                  Snowy
# 1            AquaCity          Flying Car            Solar Flare
# 2           Neuroburg  Autonomous Vehicle            Solar Flare
# 3           Ecoopolis               Drone                  Clear
# 4            AquaCity  Autonomous Vehicle            Solar Flare
# ...               ...                 ...                    ...
# 1219562  SolarisVille  Autonomous Vehicle  Electromagnetic Storm
# 1219563   MetropolisX               Drone                  Snowy
# 1219564     Neuroburg  Autonomous Vehicle                  Snowy
# 1219565   MetropolisX  Autonomous Vehicle                  Clear
# 1219566     Ecoopolis               Drone  Electromagnetic Storm
#
#         Economic Condition Day Of Week  Hour Of Day     Speed  Is Peak Hour  \
# 0                   Stable      Sunday           20   29.4268             0
# ...

# %%
df.shape
# Out:
# (1219567, 11)

# %%
df.head()
# Out:
#            City        Vehicle Type      Weather Economic Condition  \
# 0  SolarisVille               Drone        Snowy             Stable
# 1      AquaCity          Flying Car  Solar Flare          Recession
# 2     Neuroburg  Autonomous Vehicle  Solar Flare          Recession
# 3     Ecoopolis               Drone        Clear            Booming
# 4      AquaCity  Autonomous Vehicle  Solar Flare             Stable
#
#   Day Of Week  Hour Of Day     Speed  Is Peak Hour  Random Event Occurred  \
# 0      Sunday           20   29.4268             0                      0
# 1   Wednesday            2  118.8000             0                      0
# 2   Wednesday           16  100.3904             0                      0
# 3    Thursday            8   76.8000             1                      0
# 4    Saturday           16   45.2176             0                      0
#
#    Energy Consumption  Traffic Density
# 0             14.7134           0.5241
# ...

# %%
df.tail()
# Out:
#                  City        Vehicle Type                Weather  \
# 1219562  SolarisVille  Autonomous Vehicle  Electromagnetic Storm
# 1219563   MetropolisX               Drone                  Snowy
# 1219564     Neuroburg  Autonomous Vehicle                  Snowy
# 1219565   MetropolisX  Autonomous Vehicle                  Clear
# 1219566     Ecoopolis               Drone  Electromagnetic Storm
#
#         Economic Condition Day Of Week  Hour Of Day    Speed  Is Peak Hour  \
# 1219562            Booming   Wednesday           13  75.7534             0
# 1219563            Booming    Saturday            1  24.7660             0
# 1219564            Booming      Monday           19  75.6292             0
# 1219565            Booming      Monday            1  52.7983             0
# 1219566             Stable    Saturday           22  86.4000             0
#
#          Random Event Occurred  Energy Consumption  Traffic Density
# ...

# %%
df.describe()
# Out:
#         Hour Of Day         Speed  Is Peak Hour  Random Event Occurred  \
# count  1.219567e+06  1.219567e+06  1.219567e+06           1.219567e+06
# mean   1.150817e+01  5.994476e+01  1.546992e-01           4.988738e-02
# std    6.919071e+00  2.663203e+01  3.616178e-01           2.177123e-01
# min    0.000000e+00  6.693400e+00  0.000000e+00           0.000000e+00
# 25%    6.000000e+00  3.753310e+01  0.000000e+00           0.000000e+00
# 50%    1.200000e+01  5.847110e+01  0.000000e+00           0.000000e+00
# 75%    1.700000e+01  8.053455e+01  0.000000e+00           0.000000e+00
# max    2.300000e+01  1.630886e+02  1.000000e+00           1.000000e+00
#
#        Energy Consumption  Traffic Density
# count        1.219567e+06     1.219567e+06
# mean         4.946464e+01     2.770960e-01
# std          2.528014e+01     2.191019e-01
# min          4.929600e+00     5.900000e-03
# 25%          2.927395e+01     1.059000e-01
# 50%          4.578260e+01     2.186000e-01
# ...

# %%
df.nunique()
# Out:
# City                          6
# Vehicle Type                  4
# Weather                       5
# Economic Condition            3
# Day Of Week                   7
# Hour Of Day                  24
# Speed                    670544
# Is Peak Hour                  2
# Random Event Occurred         2
# Energy Consumption       665672
# Traffic Density           14209
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1219567 entries, 0 to 1219566
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   City                   1219567 non-null  object
#  1   Vehicle Type           1219567 non-null  object
#  2   Weather                1219567 non-null  object
#  3   Economic Condition     1219567 non-null  object
#  4   Day Of Week            1219567 non-null  object
#  5   Hour Of Day            1219567 non-null  int64
#  6   Speed                  1219567 non-null  float64
#  7   Is Peak Hour           1219567 non-null  int64
#  8   Random Event Occurred  1219567 non-null  int64
#  9   Energy Consumption     1219567 non-null  float64
#  10  Traffic Density        1219567 non-null  float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 102.4+ MB

# %%
df["Hour Of Day"]=df["Hour Of Day"].astype('category')
df["Is Peak Hour"]=df["Is Peak Hour"].astype('category')
df["Random Event Occurred"]=df["Random Event Occurred"].astype('category')

# %%
categorical_columns=["City","Vehicle Type","Weather","Economic Condition","Day Of Week"]
df[categorical_columns]=df[categorical_columns].astype('category')

# %%
df.dtypes
# Out:
# City                     category
# Vehicle Type             category
# Weather                  category
# Economic Condition       category
# Day Of Week              category
# Hour Of Day              category
# Speed                     float64
# Is Peak Hour             category
# Random Event Occurred    category
# Energy Consumption        float64
# Traffic Density           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# City                     0
# Vehicle Type             0
# Weather                  0
# Economic Condition       0
# Day Of Week              0
# Hour Of Day              0
# Speed                    0
# Is Peak Hour             0
# Random Event Occurred    0
# Energy Consumption       0
# Traffic Density          0
# dtype: int64

# %%
df.City.unique()
# Out:
# ['SolarisVille', 'AquaCity', 'Neuroburg', 'Ecoopolis', 'TechHaven', 'MetropolisX']
# Categories (6, object): ['AquaCity', 'Ecoopolis', 'MetropolisX', 'Neuroburg', 'SolarisVille', 'TechHaven']

# %%
df.loc[10, 'City']
# Out:
# 'Neuroburg'

# %%
df.sort_values(by='Speed', ascending=True)
# Out:
#               City        Vehicle Type      Weather Economic Condition  \
# 169483   TechHaven  Autonomous Vehicle  Solar Flare            Booming
# 780779   TechHaven  Autonomous Vehicle        Rainy          Recession
# 835523   TechHaven  Autonomous Vehicle        Snowy            Booming
# 245518   TechHaven          Flying Car        Snowy          Recession
# 637720   TechHaven  Autonomous Vehicle  Solar Flare            Booming
# ...            ...                 ...          ...                ...
# 692527   Neuroburg  Autonomous Vehicle  Solar Flare          Recession
# 1206537  Neuroburg  Autonomous Vehicle  Solar Flare          Recession
# 729908   Neuroburg  Autonomous Vehicle  Solar Flare          Recession
# 111743   Neuroburg  Autonomous Vehicle  Solar Flare          Recession
# 734177   Neuroburg  Autonomous Vehicle        Clear          Recession
#
#         Day Of Week Hour Of Day     Speed Is Peak Hour Random Event Occurred  \
# ...

# %%
np.array([df])
# Out:
# array([[['SolarisVille', 'Drone', 'Snowy', ..., 0, 14.7134, 0.5241],
#         ['AquaCity', 'Flying Car', 'Solar Flare', ..., 0, 143.5682,
#          0.3208],
#         ['Neuroburg', 'Autonomous Vehicle', 'Solar Flare', ..., 0,
#          91.264, 0.0415],
#         ...,
#         ['Neuroburg', 'Autonomous Vehicle', 'Snowy', ..., 0, 61.8568,
#          0.0564],
#         ['MetropolisX', 'Autonomous Vehicle', 'Clear', ..., 0, 85.7116,
#          0.5079],
#         ['Ecoopolis', 'Drone', 'Electromagnetic Storm', ..., 1, 49.5233,
#          0.3182]]], dtype=object)

# %%
df[:5]
# Out:
#            City        Vehicle Type      Weather Economic Condition  \
# 0  SolarisVille               Drone        Snowy             Stable
# 1      AquaCity          Flying Car  Solar Flare          Recession
# 2     Neuroburg  Autonomous Vehicle  Solar Flare          Recession
# 3     Ecoopolis               Drone        Clear            Booming
# 4      AquaCity  Autonomous Vehicle  Solar Flare             Stable
#
#   Day Of Week Hour Of Day     Speed Is Peak Hour Random Event Occurred  \
# 0      Sunday          20   29.4268            0                     0
# 1   Wednesday           2  118.8000            0                     0
# 2   Wednesday          16  100.3904            0                     0
# 3    Thursday           8   76.8000            1                     0
# 4    Saturday          16   45.2176            0                     0
#
#    Energy Consumption  Traffic Density
# 0             14.7134           0.5241
# 1            143.5682           0.3208
# ...

# %%
df[::100]
# Out:
#                  City        Vehicle Type                Weather  \
# 0        SolarisVille               Drone                  Snowy
# 100         Ecoopolis  Autonomous Vehicle                  Snowy
# 200         Ecoopolis               Drone                  Rainy
# 300         Neuroburg  Autonomous Vehicle  Electromagnetic Storm
# 400          AquaCity  Autonomous Vehicle  Electromagnetic Storm
# ...               ...                 ...                    ...
# 1219100   MetropolisX  Autonomous Vehicle                  Clear
# 1219200      AquaCity  Autonomous Vehicle                  Rainy
# 1219300  SolarisVille          Flying Car                  Clear
# 1219400      AquaCity               Drone                  Rainy
# 1219500     TechHaven  Autonomous Vehicle                  Rainy
#
#         Economic Condition Day Of Week Hour Of Day     Speed Is Peak Hour  \
# 0                   Stable      Sunday          20   29.4268            0
# ...

# %% [markdown]
# # Data Visualisation using Various Graphs

# %% [markdown]
# # ENERGY CONSUMPTION

# %% [markdown]
# # Which city has the highest energy consumption??

# %%
avg_energy_by_city = df.groupby('City')['Energy Consumption'].mean().sort_values()
avg_energy_by_city.plot(kind='bar', title=' Energy Consumption by City')
plt.xlabel('City')
plt.ylabel('Average Energy Consumption')
plt.show()

# %%
data1=df
sns.barplot(x='City', y='Energy Consumption', data = data1)
plt.show()

# %% [markdown]
# # Which vehicle consumes high energy??

# %%
avg_energy_by_city = df.groupby('Vehicle Type')['Energy Consumption'].mean().sort_values()
avg_energy_by_city.plot(kind='bar', title='Energy Consumption by Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Average Energy Consumption')
plt.show()

# %% [markdown]
# # At what time the energy was consumed the most ??

# %%
energy_by_hour = df.groupby('Hour Of Day')['Energy Consumption'].mean()
energy_by_hour.plot(kind='line', title='Energy Consumption Variation by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Average Energy Consumption')
plt.show()

# %% [markdown]
# # On which day energy was consumed the most??

# %%
energy_by_hour = df.groupby('Day Of Week')['Energy Consumption'].mean()
energy_by_hour.plot(kind='line', title='Energy Consumption Variation by  Day Of Week')
plt.xlabel('Day Of Week')
plt.ylabel('Average Energy Consumption')
plt.show()

# %% [markdown]
# # In which weather the energy was consumed the most??

# %%
sns.lineplot(x='Weather', y='Energy Consumption', data=df)
# Out:
# <AxesSubplot:xlabel='Weather', ylabel='Energy Consumption'>

# %% [markdown]
# # TRAFFIC DENSITY

# %% [markdown]
# # In which Weather the traffic density was high??

# %%
avg_traffic_by_weather = df.groupby('Weather')['Traffic Density'].mean().sort_values()
avg_traffic_by_weather.plot(kind='bar', title='Average Traffic Density by Weather')
plt.xlabel('Weather')
plt.ylabel('Average Traffic Density')
plt.show()

# %% [markdown]
# # Which city had the highest traffic density??

# %%
avg_traffic_by_weather = df.groupby('City')['Traffic Density'].mean().sort_values()
avg_traffic_by_weather.plot(kind='bar', title='Average Traffic Density by City')
plt.xlabel('City')
plt.ylabel('Average Traffic Density')
plt.show()

# %% [markdown]
# # On which day the traffic density was the highest ??

# %%
traffic_by_day = df.groupby('Day Of Week')['Traffic Density'].mean()
traffic_by_day.plot(kind='line', title='Traffic Density Variation by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Traffic Density')
plt.show()

# %% [markdown]
# # Which vehicle contributed the most to traffic density ??

# %%
sns.barplot(x='Vehicle Type', y='Traffic Density', data = data1)
plt.show()

# %% [markdown]
# # At what time  traffic density was on peak??

# %%
traffic_by_day = df.groupby('Hour Of Day')['Traffic Density'].mean()
traffic_by_day.plot(kind='line', title='Traffic Density Variation by Hour of Day')
plt.xlabel('Hour Of Day')
plt.ylabel('Average Traffic Density')
plt.show()

# %% [markdown]
# # SPEED VS VEHICLE TYPE

# %%
sns.lineplot(x='Vehicle Type', y='Speed', data=df)
# Out:
# <AxesSubplot:xlabel='Vehicle Type', ylabel='Speed'>

# %% [markdown]
# # SPEED VS HOUR OF THE DAY

# %%
sns.boxplot(x='Hour Of Day', y='Speed', data = data1)
# Out:
# <AxesSubplot:xlabel='Hour Of Day', ylabel='Speed'>
